# %% [markdown]
# <div><center><img src="https://ml.ucv.ai/logo.png\" width=150"/> </center></div>

# %% [markdown]
# # 02 Parcial teórico 2
#
# ## Aprendizaje Automático [UCV]
#
#
# * Alumno: NOMBRE Y APELLIDO
# * Cédula: CÉDULA DE IDENTIDAD
# ----

# %% [markdown]
# Fecha y Hora de entrega: **Lunes 14 de Octubre a las 11:59 am**.
# - Exámenes luego de la hora establecida no serán corregidos

# %% [markdown]
# El examen consta de dos secciones una teórica y una práctica.
#
#
# Me interesa entender su comprensión de los temas por lo que el examen es 100% a libre a libro abierto pero debe justificar **todas** sus respuestas.
#
# Si utilizó una referencia, coloque link (de ser online) o nombre de trabajo, autor/es y página (de ser una referencia escrita de libro o paper).
# - De ser para la sección teórica, debe reescribir o parafrasear con sus propias palabras la sección que desea usar y porqué la usó en la pregunta.
# - De ser para la sección práctica, comente lo más posible el código usado de un tercero.

# %% [markdown]
# # Preguntas teóricas

# %% [markdown]
# ## 1.1
#
# Explique brevemente tres diferencias fundamentales entre resolver un problema de regresión con redes neuronales versus la formulación estándar?

# %% [markdown]
# ### 1.1.b Respuesta
#
# ACÁ SU *RESPUESTA*

# %% [markdown]
# ## 1.2
#
# Considere el siguiente código escrito en PyTorch

# %%
import torch
import torch.nn as nn


class ModeloSimple(nn.Module):
    def __init__(
        self,
        z,
        w,
        y
    ):
        super(ModeloSimple, self).__init__()
        self.fc1 = nn.Linear(
            in_features=y,
            out_features=z
        )
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(
            in_features=z,
            out_features=w
        )

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# Modifique el código y substituya las variables y, w, y z por las variables de entrada, salida y capas ocultas. Además, agregue la opción de usar como función de activación además de la presentada la tangente hiperbólica.

# %% [markdown]
# ### 1.2.b Respuesta
#
# SELECCIONE LA O LAS OPCIONES Y JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# ## 1.3
#
# Supongamos que modificamos la función de activación $f_i$ en las neuronas de la capa oculta de una red neuronal a la siguiente expresión:
#
# $$f_i(x, y) = a_i x + b_i y + c_i \text{ con } i \in \{1,2, 3\}$$
#
# La estructura de la red tiene 2 capas de entrada 1 capa oculta con 3 neuronas y 1 salida.
#
# 1. Escriba el diagrama de la red.
# 1. Qué particularidad tiene la función resultante?

# %% [markdown]
# ### 1.3.b Respuesta
#
# JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# ## 1.4 Pregunta de clase 1
#
# Gráfico tomado de [Coefficient of determination](https://en.wikipedia.org/wiki/Coefficient_of_determination)
#
# ![image.png](data:image/png;base64,...)
#
# $$R^2=1-\frac{\color{blue}{S S_{\mathrm{res}}}}{\color{red}{S S_{\mathrm{tot}}}}$$
#
# De donde $$\color{blue}{S S_{\mathrm{res}}} = \sum_i\left(y_i-f(x_i)\right)^2=\sum_i e_i^2  $$ y $$\color{red}{S S_{\mathrm{tot}}} = \sum_i\left(y_i-\bar{y}\right)^2 $$
#
# 1. Por qué usamos $\bar{y}$ en el denominador $\color{red}{S S_{\mathrm{tot}}}$?
# 1. Es el único posible valor que podemos usar?
# 1. Vean como el denominador es **constante** para todos los posibles modelos! Por qué?

# %% [markdown]
# ### 1.4  Respuesta
#
# SELECCIONE LA O LAS OPCIONES Y JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# ## 1.5
#
# Supongamos que tenemos cuatro centroides y estamos usando K-medias con distancia euclideana.
#
# Los centroides son: $$c_1 = \begin{pmatrix} 1 \\ 0 \\ 2 \\ -4 \end{pmatrix},
# c_2 = \begin{pmatrix} 10 \\ 1 \\ -4 \\ -4 \end{pmatrix}, c_3 = \begin{pmatrix} 5 \\ 6 \\ 1 \\ 0 \end{pmatrix}, c_4 = \begin{pmatrix} 2 \\ 10 \\ 2 \\ -8 \end{pmatrix}
# $$
#
# Asigne los siguientes puntos a cada clúster:
#
# 1. $$p_1 = \begin{pmatrix} 1.5 \\ -0.5 \\ 2.9 \\ -2.5 \end{pmatrix} $$
# 1. $$p_2 = \begin{pmatrix} 13 \\ 0 \\ -3.6 \\ -9 \end{pmatrix}$$
# 1. $$p_3 = \begin{pmatrix} 50 \\ -2 \\ 10 \\ -5 \end{pmatrix}$$
# 1. $$p_4 = \begin{pmatrix} -2 \\ -10 \\ -2 \\ 8 \end{pmatrix} $$

# %% [markdown]
# ### 1.5  Respuesta
#
# SELECCIONE LA O LAS OPCIONES Y JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# ## 1.6
#
# Asumiendo el escenario anterior de 1.5 responda las siguientes preguntas:
#
#
#
# - Si tuviesen que identificar 1 valor extremo (outlier) cómo harían?
# - Realice una iteración para refrescar los centros $c_i$.
# - Bajo qué escenario tendría sentido usar la distancia de Manhattan en K-medias? Qué habría que modificar?

# %% [markdown]
# ### 1.6  Respuesta
#
# JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# ## 1.7
#
# Consideremos el algoritmo de K-medias y escogemos como k=3. Asuma que el criterio de escogencia es la distancia euclideana. Una configuración de grupos/clústers se considera "estable" si una iteración extra del algoritmo mantiene los grupos/clústers inalterados.
#
# Dados los siguientes puntos:
#
# ![image.png](data:image/png;base64,...)
#
# Cuál de los siguientes grupos/clústers es estable? Escriba claramente sus cálculos.
#
# 1. {{b, e}, {c, f}, {a, d}}
# 1. {{c, f}, {d, e}, {a, b}}
# 1. {{a, b, e}, {f}, {c, d}}
# 1. {{d}, {a, b}, {c, e, f}}
# 1. {{d}, {b, c, e, f}, {a}}

# %% [markdown]
# ### 1.7  Respuesta
#
# JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# ## 1.8
#
# Imaginen que tenemos un modelo de clasificación con dos clases y aumentamos el umbral de clasificación. Qué sucede con la sensibilidad (TRP) del modelo?
#
# 1. Se puede mantener igual.
# 1. Siempre se mantiene constante ya que el umbral no afecta la sensibilidad.
# 1. La sensibilidad puede disminuir.
# 1. La sensibilidad puede aumentar.
#
# Mencione un caso hipotético donde disminuir la sensibilidad tenga sentido.

# %% [markdown]
# ### 1.8  Respuesta
#
# SELECCIONE LA O LAS OPCIONES Y JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# 1.9
#
# Una empresa le contrata para encontrar una buena disposición de cajas en un almacén. Para ello, deben agruparlas dependiendo del número de trabajadores que puedan moverlas. Todas las cajas son iguales. Debido a limitaciones de tiempo, necesitan comparar varias disposiciones (modificando el número de trabajadores a contratar) de tal manera que luego escojan una disposición que minimice el dinero invertido pero maximice la eficiencia del movimiento de los grupos de cajas. Afortunadamente para ustedes, el algoritmo que calcula dinero invertido y eficiencia ya está hecho.
#
# Escriba un enfoque para resolver el problema anterior. No debe contener código, explique qué haría y porqué. Asuma que está hablando con un científico de datos.

# %% [markdown]
# ### 1.9  Respuesta
#
# JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# 1.10
#
# Si tenemos dos modelos $M_1$ y $M_2$ entrenados en los mismos datos con los mismos splits. Dados los siguientes escenarios:
#
# 1. Si $M_2$ tiene mejor precisión que $M_1$ entonces $M_2$ funciona mucho mejor que $M_1$
# 1. Si $M_2$ tiene peor precisión y peor sensibilidad que $M_1$ entonces con alta probabilidad funciona peor que $M_1$
# 1. Si $M_2$ tiene peor sensibilidad que $M_1$ entonces $M_1$ funciona mucho mejor que $M_2$
# 1. Si $M_1$ tiene mejor precisión y mejor sensibilidad que $M_2$ entonces con alta probabilidad funciona peor que $M_2$

# %% [markdown]
# ### 1.10  Respuesta
#
# SELECCIONE LA O LAS OPCIONES Y JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# ## 1.11
#
# Suponga tiene los siguientes puntos:
#
# A: (2, 10, 3, 7)
# B: (2, 5, 6, 1)
# C: (8, 4, 9, 3)
# D: (5, 8, 2, 4)
# E: (7, 5, 6, 2)
# F: (6, 4, 8, 5)
# G: (9, 9, 4, 6)
# H: (1, 3, 7, 9)
#
# 1. Explique paso a paso cómo se modifica la matriz de distancias al usar el algoritmo de agrupamiento jerárquico con distancia euclidiana como métrica de distancia y el enlace promedio como criterio de enlace.
# 1. Grafique el dendrograma resultante.

# %% [markdown]
# ### 1.11  Respuesta
#
# JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# ## 1.12
#
# Explique detalladamente las siguientes preguntas:
#
# 1. Qué son y para qué usamos las curvas ROC?
# 1. Explique con sus propias palabras la razón por la cual escogemos TRP y FPR como ejes de las curvas ROC
# 1. Qué es AUC? Cómo la usamos? Cuál es su valor máximo?
# 1. Qué limitaciones tiene esta técnica si decidimos usarla?

# %% [markdown]
# ### 1.12  Respuesta
#
#
# JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# ## 1.13
#
# 1. Explique la funcionalidad del método del codo para el algoritmo K-medias.
# 1. Cuál es el mejor K posible donde tendríamos "error" mínimo?
# 1. Podemos usar este método en agrupamiento jerárquico? Por qué?

# %% [markdown]
# ### 1.13  Respuesta
#
# JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# ## 1.14
#
# Describa el concepto de validación cruzada y explique por qué es importante en la evaluación de modelos de aprendizaje automático.

# %% [markdown]
# ### 1.14  Respuesta
#
# JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# ## 1.15
#
# 1. Es posible representar la siguiente función booleana usando la Threshold Logic Unit?
#
# | p | q | p X q |
# |:-:|:-:|:-----:|
# | 1 | 1 |   0   |
# | 1 | 0 |   1   |
# | 0 | 1 |   0   |
# | 0 | 0 |   0   |
#
# 2. Identifique la función X
# 3. Escriba el diagrama de la red neuronal usando los pesos vistos en clases.
# 4. Implemente la función en PyTorch y evalúela.
# 5. [Opcional] Intente implementar $(\neg p \land q \land w) \lor (\neg q \land \neg p)
# $

# %% [markdown]
# ### 1.15  Respuesta
#
# JUSTIFIQUE SU RESPUESTA

# %% [markdown]
# # Parte práctica (15 puntos)
#
# ## ANY-P-OUT-medias
#
# Implemente un algoritmo que automáticamente seleccione el valor de K y lo retorne junto a los grupos y además elimine P valores extremos.
#
# 1. ANY-P-OUT-medias asume como entrada una matriz de numpy con $N$ filas y $M$ columnas.
# 1. ANY-P_OUT-medias debe ser implementado por ustedes. Solo pueden usar numpy y scipy para operaciones entre matrices y vectores.
# 1. Escriba detalladamente aspectos de diseño:
#   - Cómo inicializan los centroides?
#   - Cuál criterio de convergencia usan?
#   - Cómo escogen K?
#   - Cómo eliminan los P puntos?
# 1. Provea uno o más métodos de graficación donde sea intuitivo ver la elección de los P valores extremos y de los K clústers.
#
# Nota:
#   - No hay respuesta única: no voy a comparar enfoques entre ustedes. Si justifican bien cada punto lo considero correcto.
#   - No usen GenAI en este ejercicio.

# %% [markdown]
# ## Optimize it!
#
# Considere la siguiente superficie $$
# f(x, y)=\frac{\sin \left(0.8 \left(x^2+y^2\right)\right)}{\left(x^2+y^2\right)^{0.9}}
# $$

# %%
import matplotlib.pyplot as plt
import torch
import matplotlib.cm as cm
import copy
import time

# %% [markdown]
# ### Implemente la función usando `torch.sin` disponible en [PyTorch - Sin](https://pytorch.org/docs/stable/generated/torch.sin.html)

# %%
def f(x, y):
    return # Modificar código

# %% [markdown]
# ### Parámetros de generación de datos

# %%
ruido = 0
mesh_dim = 40

# %% [markdown]
# ### Funciones para generar los datos

# %%
def datos(ruido, mesh_dim):
  t = torch.linspace(-3, 3, mesh_dim)
  x, y = torch.meshgrid(t, t)
  z = f(x, y)
  z_noisy = z + ruido * torch.randn(mesh_dim, mesh_dim)

  return x, y, z, z_noisy

def dataset(x, y, z, z_noisy):
  x_train = torch.vstack([x.ravel(), y.ravel()]).T
  y_train = z_noisy.ravel()
  y_test = z.ravel()

  return x_train, y_train, y_test

def plot_surface(x, y, z_noisy):
  fig = plt.figure()
  ax = plt.axes(projection='3d')
  ax.plot_surface(x, y, z_noisy,cmap='viridis', edgecolor='none')
  ax.set_title('Superficie')
  plt.show()

# %%
x, y, z, z_ruido = datos(ruido, mesh_dim)

# %%
plot_surface(x, y, z_ruido)

# %%
x_train, y_train, y_test = dataset(x, y, z, z_ruido)

# %% [markdown]
# ### Definiendo el modelo

# %% [markdown]
# La siguiente clase intenta definir una arquitectura de red neuronal que debe aproximar a $f(x, y)$. Identifique las dimensiones (entrada, salida) de la red sin importar la arquitectura.

# %% [markdown]
# Respuesta:

# %% [markdown]
# Se provee la estructura principal de la clase debe crear la arquitectura en el método `__init__` de tal manera de que tenga 3 capas lineales con dimensiones de entrada `neuronas_l1`, `neuronas_l2` y `neuronas_l3`. La función de activación debe ser la `ReLU` para todas las capas.

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

# %%
class Net3L(nn.Module):
    def __init__(self, neuronas_l1=10, neuronas_l2=10, neuronas_l3=10):
        super(Net3L, self).__init__()
        ##############################################
        #         Agregue red neuronal acá           #
        ##############################################
        self.linear_relu_stack = # Agregar modelo
        ##############################################
    def forward(self, x):
        return self.linear_relu_stack(x)

    def fit(self, x_train, y_train, optimizer, batch_size, n_epochs_max):
        # Crear el TensorDataset
        train_data = TensorDataset(None, None)

        # Crear el Data Loader
        train_loader = DataLoader(
            dataset=None, # 3
            batch_size=None,
            shuffle= True # 4
        )

        # Creando el loop de entrenamiento
        loss_list = []
        for n_epochs in range(n_epochs_max):
            # We train for a fixed number of epochs
            for x_batch, y_batch in train_loader:
                def closure():
                    optimizer.zero_grad()
                    output = None # 5
                    loss = nn.MSELoss()(output.squeeze(-1), y_batch)
                    loss.backward()
                    return loss
                loss = optimizer.step(closure)
            loss_list.append(loss.item())
        return loss_list

    def evaluate(self, x_test, y_test):
      y_pred = self(x_test).squeeze(-1)
      return (nn.MSELoss()(y_pred, y_test)).item()

# %% [markdown]
# ### Entrenamiento
#
# Modifique la entrada para que la capa lineal 1 tenga 60 neuronas, la 2 30 neuronas y la 3 20 neuronas.

# %%
net = Net3L(None, None, None)

# %% [markdown]
# Modifique los valores en None

# %%
loss_list = net.fit(
    None, None,
    torch.optim.LBFGS(net.parameters(), lr=1, max_iter=1, line_search_fn='strong_wolfe'),
    1600, 2000
)

# %% [markdown]
# ### Evaluación
#
# Explique detalladamente la funcionalidad del siguiente gráfico y de nombre a los ejes

# %%
plt.figure()
plt.xlabel('Nombre 1')
plt.ylabel('Nombre 2')
plt.plot(loss_list)
plt.show()

# %% [markdown]
# ### Predicción

# %%
y_pred = net(x_train).detach().squeeze(-1)

# %%
def plot_result(x, y, z1, z2):
  fig, ax = plt.subplots(1, 2, figsize=(10, 10), subplot_kw={'projection': '3d'})
  #
  ax[0].plot_trisurf(x, y, z1, vmin=y_train.min(), cmap=cm.viridis)
  ax[0].set_xlabel('x')
  ax[0].set_ylabel('y')
  ax[0].set_zlabel('z')
  ax[0].set_title('Superficie')
  #
  ax[1].plot_trisurf(x, y, (z1-z2)**2, vmin=0, cmap=cm.viridis)
  ax[1].set_xlabel('x')
  ax[1].set_ylabel('y')
  ax[1].set_zlabel('z')
  ax[1].set_title('Residuales cuadrados')
  plt.show()

# %% [markdown]
# Modifique la llamada de la siguiente función de tal manera que el primer gráfico muestre la superficie luego de la predicción y la segunda superfice la diferencia cuadrática entre predicciones y valores reales

# %%
plot_result(None, None, None, None)

# %% [markdown]
# Finalmente, modifique el código para obtener el  error de entrenamiento y el error de prueba. Compare los valores.

# %%
print('Error entrenamiento:', net.evaluate(None, None))
print('Error de prueba:', net.evaluate(None, None))

# %% [markdown]
# ### Analizando distintos optimizers

# %% [markdown]
# El siguiente segmento de código tarda alrededor de 5 minutos por cada ejecución. Su objetivo es investigar las diferencias entre los 3 optimizadores utilizados y responder las siguientes preguntas:
#
# 1. Cuál es el impacto del parámetro `ruido` en el proceso de optimización?
# 1. Cómo se diferencia el método del descenso del gradiente (parcial 1) con el descenso estocástico y las versiones aceleradas?
# 1. Cómo impacta la dimensión de la red neuronal en el rendimiento del optimizador?
# 1. Intente analizar la diferencia entre épocas y el tiempo de convergencia de los algoritmos.

# %%
# Crear la red con numero de neuronas idéntico para cada capa
net = Net3L(50, 50, 50)

# Creamos una copia de la red de tal manera de que compartan la misma inicialización
net_list = [copy.deepcopy(net) for i in range(5)]

# Modifique a conveniencia el número de épocas para responder sus preguntas.
n_epochs = 2500
optim1 = torch.optim.SGD(params=net_list[0].parameters(), lr=0.05)
optim2 = torch.optim.SGD(params=net_list[1].parameters(), lr=0.1)
optim3 = torch.optim.SGD(params=net_list[2].parameters(), lr=0.1, momentum=0.9, nesterov= True)
optim4 = torch.optim.Adam(params=net_list[3].parameters())
optim5 = torch.optim.LBFGS(params=net_list[4].parameters(), lr=1, max_iter=1, line_search_fn='strong_wolfe')

optimizer_list = [optim1, optim2, optim3, optim4, optim5]
batch_sizes_list = [1600, 40, 400, 400, 1600]
times_list = []
loss_meta_list = []
eval_list = []

for i, optimizer in enumerate(optimizer_list):
    t0 = time.time()
    loss_list = net_list[i].fit(x_train, y_train, optimizer= optimizer, batch_size= batch_sizes_list[i], n_epochs_max= n_epochs)
    t1 = time.time()
    times_list.append(t1-t0)
    loss_meta_list.append(loss_list)
    eval_list.append(net_list[i].evaluate(x_train, y_test))

# %% [markdown]
# ## Shallow MNIST  vs Standard ML
#
# Implemente en PyTorch y usando el dataset MNIST una red neuronal con X capas ocultas y número variable de neuronas por capa y compare resultados con K-vecinos y máquinas de soporte vectorial dependiendo de la X y de K.
#
# 1. Explique *detalladamente* la razón del rendimiento de los métodos.
# 1. Cómo podrían compararlos de manera "justa"?
